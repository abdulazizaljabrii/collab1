# %%
import numpy as np
from PIL import Image

# %%
image = Image.open('/Users/azozaljabri/Desktop/dog-puppy-on-garden-royalty-free-image-1586966191.jpeg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1197 at 0x7F79411715B0>

# %%
image = image.convert('RGB')

# %%
pixels = image.load()

# %%
 for i in range(image.width):
    for j in range (image.height):
        r, g, b=pixels[i,j]

# %%
r +=50

# %%
r = 255 - r
g = 255 - g 
b = 255 - b

# %%
pixels [i,j] = (r , g , b)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1197 at 0x7F7941031970>
